# %%
# import libraries
from datetime import datetime, timedelta, date
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', 1000)
pd.set_option('display.min_rows', 1000)

# %% [markdown]
# ## PartOfMonth Purchases Item – Mean & StdD

# %%
#Read csv
dmc_data = pd.read_csv('E:\OneDrive\Arbeit\Repos\DMC2022\Kevin\DMC_2022_task\orders.csv', sep='|')

# %%
dmc_data.head()
# Out:
#          date  userID  itemID  order
# 0  2020-06-01   38769    3477      1
# 1  2020-06-01   42535   30474      1
# 2  2020-06-01   42535   15833      1
# 3  2020-06-01   42535   20131      1
# 4  2020-06-01   42535    4325      1

# %%
# Convert 'date' column to datetime format
dmc_data['date'] = pd.to_datetime(dmc_data['date'], format="%Y-%m-%d")
dmc_data.dtypes

# %%
# Add column 'week'
dmc_data['week'] = ''
dmc_data.head()

# %%
# Add entries for 'week' based on dates

#06 Jun
dmc_data.loc[(dmc_data['date'] >= datetime(2020,6,1)) & (dmc_data['date'] <= datetime(2020,6,7)), ['week']] = 1
dmc_data.loc[(dmc_data['date'] >= datetime(2020,6,8)) & (dmc_data['date'] <= datetime(2020,6,14)), ['week']] = 2
dmc_data.loc[(dmc_data['date'] >= datetime(2020,6,15)) & (dmc_data['date'] <= datetime(2020,6,21)), ['week']] = 3
dmc_data.loc[(dmc_data['date'] >= datetime(2020,6,22)) & (dmc_data['date'] <= datetime(2020,6,30)), ['week']] = 4

#07 Jul
dmc_data.loc[(dmc_data['date'] >= datetime(2020,7,1)) & (dmc_data['date'] <= datetime(2020,7,5)), ['week']] = 1
dmc_data.loc[(dmc_data['date'] >= datetime(2020,7,8)) & (dmc_data['date'] <= datetime(2020,7,14)), ['week']] = 2
dmc_data.loc[(dmc_data['date'] >= datetime(2020,7,15)) & (dmc_data['date'] <= datetime(2020,7,21)), ['week']] = 3
dmc_data.loc[(dmc_data['date'] >= datetime(2020,7,22)) & (dmc_data['date'] <= datetime(2020,7,31)), ['week']] = 4

#08 Aug
dmc_data.loc[(dmc_data['date'] >= datetime(2020,8,1)) & (dmc_data['date'] <= datetime(2020,8,7)), ['week']] = 1
dmc_data.loc[(dmc_data['date'] >= datetime(2020,8,8)) & (dmc_data['date'] <= datetime(2020,8,14)), ['week']] = 2
dmc_data.loc[(dmc_data['date'] >= datetime(2020,8,15)) & (dmc_data['date'] <= datetime(2020,8,21)), ['week']] = 3
dmc_data.loc[(dmc_data['date'] >= datetime(2020,8,22)) & (dmc_data['date'] <= datetime(2020,8,31)), ['week']] = 4

#09 Sep
dmc_data.loc[(dmc_data['date'] >= datetime(2020,9,1)) & (dmc_data['date'] <= datetime(2020,9,7)), ['week']] = 1
dmc_data.loc[(dmc_data['date'] >= datetime(2020,9,8)) & (dmc_data['date'] <= datetime(2020,9,14)), ['week']] = 2
dmc_data.loc[(dmc_data['date'] >= datetime(2020,9,15)) & (dmc_data['date'] <= datetime(2020,9,21)), ['week']] = 3
dmc_data.loc[(dmc_data['date'] >= datetime(2020,9,22)) & (dmc_data['date'] <= datetime(2020,9,30)), ['week']] = 4

#10 Oct
dmc_data.loc[(dmc_data['date'] >= datetime(2020,10,1)) & (dmc_data['date'] <= datetime(2020,10,7)), ['week']] = 1
dmc_data.loc[(dmc_data['date'] >= datetime(2020,10,8)) & (dmc_data['date'] <= datetime(2020,10,14)), ['week']] = 2
dmc_data.loc[(dmc_data['date'] >= datetime(2020,10,15)) & (dmc_data['date'] <= datetime(2020,10,21)), ['week']] = 3
dmc_data.loc[(dmc_data['date'] >= datetime(2020,10,22)) & (dmc_data['date'] <= datetime(2020,10,31)), ['week']] = 4

#11 Nov
dmc_data.loc[(dmc_data['date'] >= datetime(2020,11,1)) & (dmc_data['date'] <= datetime(2020,11,7)), ['week']] = 1
dmc_data.loc[(dmc_data['date'] >= datetime(2020,11,8)) & (dmc_data['date'] <= datetime(2020,11,14)), ['week']] = 2
dmc_data.loc[(dmc_data['date'] >= datetime(2020,11,15)) & (dmc_data['date'] <= datetime(2020,11,21)), ['week']] = 3
dmc_data.loc[(dmc_data['date'] >= datetime(2020,11,22)) & (dmc_data['date'] <= datetime(2020,11,30)), ['week']] = 4

#12 Dec
dmc_data.loc[(dmc_data['date'] >= datetime(2020,12,1)) & (dmc_data['date'] <= datetime(2020,12,7)), ['week']] = 1
dmc_data.loc[(dmc_data['date'] >= datetime(2020,12,8)) & (dmc_data['date'] <= datetime(2020,12,14)), ['week']] = 2
dmc_data.loc[(dmc_data['date'] >= datetime(2020,12,15)) & (dmc_data['date'] <= datetime(2020,12,21)), ['week']] = 3
dmc_data.loc[(dmc_data['date'] >= datetime(2020,12,22)) & (dmc_data['date'] <= datetime(2020,12,31)), ['week']] = 4

#01 Jan
dmc_data.loc[(dmc_data['date'] >= datetime(2021,1,1)) & (dmc_data['date'] <= datetime(2021,1,7)), ['week']] = 1
dmc_data.loc[(dmc_data['date'] >= datetime(2021,1,8)) & (dmc_data['date'] <= datetime(2021,1,14)), ['week']] = 2
dmc_data.loc[(dmc_data['date'] >= datetime(2021,1,15)) & (dmc_data['date'] <= datetime(2021,1,21)), ['week']] = 3
dmc_data.loc[(dmc_data['date'] >= datetime(2021,1,22)) & (dmc_data['date'] <= datetime(2021,1,31)), ['week']] = 4

# Show all entries that were bought in the second week of the month
dmc_data.loc[dmc_data['week'] == 2]
# Out:
#              date  userID  itemID  order week
# 34905  2020-06-08   32250    6826      1    2
# 34906  2020-06-08   33962   25474      1    2
# 34907  2020-06-08   37840    6590      1    2
# 34908  2020-06-08   37840   19281      3    2
# 34909  2020-06-08   33962   27560      1    2
# 34910  2020-06-08   33962   26896      1    2
# 34911  2020-06-08   33962    5882      1    2
# 34912  2020-06-08   33962   11352      1    2
# 34913  2020-06-08   38372   13574      1    2
# 34914  2020-06-08   15649   16006      5    2
# 34915  2020-06-08   38372   29812      1    2
# 34916  2020-06-08   17793   18722     50    2
# 34917  2020-06-08   37493   18586      1    2
# 34918  2020-06-08   22413   18579      1    2
# 34919  2020-06-08   22413   20633      2    2
# 34920  2020-06-08   22413   17269      1    2
# 34921  2020-06-08   33962    1290      1    2
# 34922  2020-06-08   33724   17512      1    2
# 34923  2020-06-08   33724    4832      1    2
# ...

# %%
dmc_data.loc[dmc_data['week'] == 2]

# %%
mask = (df['date'] > start_date) & (df['date'] <= end_date)

# %%
dmc_data.loc[(dmc_data['date'] >= datetime(2020,6,3)) & (dmc_data['date'] <= datetime(2020,6,4))]
# Out:
#             date  userID  itemID  order Label
# 9469  2020-06-03   34317   31483      1     1
# 9470  2020-06-03    5273   17076      1     1
# 9471  2020-06-03    5273   11535      1     1
# 9472  2020-06-03    5273    8385      1     1
# 9473  2020-06-03   25829    2667      1     1
# 9474  2020-06-03   25829   12566      2     1
# 9475  2020-06-03   25829   20515      2     1
# 9476  2020-06-03   25829    4603      3     1
# 9477  2020-06-03   25829   29906      1     1
# 9478  2020-06-03   41091    8615      2     1
# 9479  2020-06-03   41091   23834      1     1
# 9480  2020-06-03   41091   27778      1     1
# 9481  2020-06-03   41091   19360      1     1
# 9482  2020-06-03   26857   14422      3     1
# 9483  2020-06-03   26857   12528      1     1
# 9484  2020-06-03   26857   26468      1     1
# 9485  2020-06-03    5273     410      1     1
# 9486  2020-06-03   18627   22963      1     1
# 9487  2020-06-03   20288     637      1     1
# ...

# %%
df = pd.DataFrame

for ind in dmc_jun.index:
    if (dmc_jun['date'] < datetime(2020,7,1)).any():
        dmc_jun['Label'][ind] = '1'
        dfmi.loc[:, ('one', 'second')]
# Out:
# C:\Users\kevin\AppData\Local\Temp\ipykernel_10016\805533922.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dmc_jun['Label'][ind] = '1'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [66], in <cell line: 3>()
#       3 for ind in dmc_jun.index:
#       4     if (dmc_jun['date'] < datetime(2020,7,1)).any():
# ----> 5         dmc_jun['Label'][ind] = '1'
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:1075, in Series.__setitem__(self, key, value)
#    1073 check_deprecated_indexers(key)
#    1074 key = com.apply_if_callable(key, self)
# -> 1075 cacher_needs_updating = self._check_is_chained_assignment_possible()
#    1077 if key is Ellipsis:
# ...

# %%
dmc

# %%
# split dataset into months

dmc_data['date'] = pd.to_datetime(dmc_data['date'], format="%Y-%m-%d")

dmc_jun = dmc_data[(dmc_data.date < datetime(2020,7,1)) & (dmc_data.date >= datetime(2020,6,1))].reset_index(drop=True)
dmc_jul = dmc_data[(dmc_data.date < datetime(2020,8,1)) & (dmc_data.date >= datetime(2020,7,1))].reset_index(drop=True)
dmc_aug = dmc_data[(dmc_data.date < datetime(2020,9,1)) & (dmc_data.date >= datetime(2020,8,1))].reset_index(drop=True)
dmc_sep = dmc_data[(dmc_data.date < datetime(2020,10,1)) & (dmc_data.date >= datetime(2020,9,1))].reset_index(drop=True)
dmc_oct = dmc_data[(dmc_data.date < datetime(2020,11,1)) & (dmc_data.date >= datetime(2020,10,1))].reset_index(drop=True)
dmc_nov = dmc_data[(dmc_data.date < datetime(2020,12,1)) & (dmc_data.date >= datetime(2020,11,1))].reset_index(drop=True)
dmc_dec = dmc_data[(dmc_data.date < datetime(2021,1,1)) & (dmc_data.date >= datetime(2020,12,1))].reset_index(drop=True)
dmc_jan = dmc_data[(dmc_data.date < datetime(2021,2,1)) & (dmc_data.date >= datetime(2021,1,1))].reset_index(drop=True)

# %%
# function for defining the fourth of a month a purchase was made

def getPartOfMonth(row):
    daysInRegMonths = [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]
    dayOfDate = row.date.day
    return dayOfDate/(daysInRegMonths[row.date.month - 1]/4)

# %%
# calculate for every purchase in what fourth of the month it was made

tables = [dmc_jun, dmc_jul, dmc_aug, dmc_sep, dmc_oct, dmc_nov, dmc_dec, dmc_jan]

for table in tables:
    table['partOfMonth'] = table.apply(getPartOfMonth, axis=1)

# %%
# group by userID & item, keep partOfMonths in list & calculate mean

#for table in tables:
    #pList = table.groupby(['userID', 'itemID'])['partOfMonth'].apply(list) # keep grouped values in list
    #table = table.groupby(['userID', 'itemID']).agg(orderSum = ('order', 'sum'))

# %%
# concantenate all months
dmc_data = pd.concat(tables)

# group by userID & itemID; sum Orders, calc STD & MEAN of partOfMonth
grouped_userItem = dmc_data.groupby(['userID', 'itemID']).agg(order_sum=('order', 'sum'), pom_std=('partOfMonth','std'), pom_mean=('partOfMonth', 'mean'))
grouped_Item = dmc_data.groupby(['itemID']).agg(order_sum=('order', 'sum'), pom_std=('partOfMonth','std'), pom_mean=('partOfMonth', 'mean'))

# drop rows with NaN and STD=0 (items, that were NOT repurchased)
grouped_userItem = grouped_userItem.dropna()
grouped_userItem = grouped_userItem.drop(grouped_userItem[grouped_userItem.pom_std == 0].index)

grouped_Item = grouped_Item.dropna()
grouped_Item = grouped_Item.drop(grouped_Item[grouped_Item.pom_std == 0].index)

# %%
grouped_Item.sort_values(by=['pom_std'], ascending=True).sort_values(by=['order_sum'], ascending=False)
# Out:
#         order_sum   pom_std  pom_mean
# itemID
# 29657       29116  1.160523  2.094671
# 18630       11888  1.163652  2.077945
# 11251        9633  1.165900  2.054425
# 20131        8061  1.165143  2.031205
# 31354        7745  0.949607  2.487455
# 23050        7031  1.162156  2.088302
# 32204        5488  1.145414  2.026612
# 16059        5258  1.164584  2.108769
# 19267        4923  1.157436  2.115938
# 1782         4663  1.161485  2.050851
# 29660        4564  1.173875  2.089095
# 1970         4054  1.146662  2.083157
# 19281        3952  1.154985  2.123857
# 26503        3723  1.166375  2.036856
# 23582        3594  1.167324  2.090019
# 24763        3592  1.166682  2.090505
# 17419        3501  1.146709  2.107953
# 637          3439  1.171643  2.081182
# 11188        3281  1.174506  2.072477
# 31702        3235  1.190026  2.066678
# 19043        3044  1.176915  2.033728
# 20150        3031  1.171818  2.106146
# 395          2948  1.153312  2.107083
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## Part of Month Purchases Category – Mean & StdD

# %%
orders = pd.read_csv('D:\Cloud\ownCloud\HAWCloud\HAW Media Systems\Kurse\Adaptive-Systems_Artificial-Intelligence\DMC_2022\DMC_2022_task\orders.csv', sep='|')

# %%
orders['date'] = pd.to_datetime(orders['date'], format="%Y-%m-%d")

orders_jun = orders[(orders.date < datetime(2020,7,1)) & (orders.date >= datetime(2020,6,1))].reset_index(drop=True)
orders_jul = orders[(orders.date < datetime(2020,8,1)) & (orders.date >= datetime(2020,7,1))].reset_index(drop=True)
orders_aug = orders[(orders.date < datetime(2020,9,1)) & (orders.date >= datetime(2020,8,1))].reset_index(drop=True)
orders_sep = orders[(orders.date < datetime(2020,10,1)) & (orders.date >= datetime(2020,9,1))].reset_index(drop=True)
orders_oct = orders[(orders.date < datetime(2020,11,1)) & (orders.date >= datetime(2020,10,1))].reset_index(drop=True)
orders_nov = orders[(orders.date < datetime(2020,12,1)) & (orders.date >= datetime(2020,11,1))].reset_index(drop=True)
orders_dec = orders[(orders.date < datetime(2021,1,1)) & (orders.date >= datetime(2020,12,1))].reset_index(drop=True)
orders_jan = orders[(orders.date < datetime(2021,2,1)) & (orders.date >= datetime(2021,1,1))].reset_index(drop=True)
